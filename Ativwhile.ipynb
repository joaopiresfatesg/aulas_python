# %%
# vExercícios A — Operadores Lógicos
#Exerc. 1 idade
idade_pessoa = int(input("digite sua idade:"))
tem_carteira = input("tem carteira de motorista?(S/N")


if idade_pessoa >= 18 and tem_carteira == 'S':
    print ("pode dirigir")
else:
    print("não pode dirigir")

# %%
# exerc 2 peça um numero
numero = int(input("digite um numero"))
if numero >=50 and numero <=100:
    print (" o numero está entre 50 e 100")
else: 
    print("o numero não está entre 50 e 100")

# %%
# exerc 3 peça dia da semana
dia_semana = input ("digite o dia da semana")
if dia_semana == 'sabado' or dia_semana== 'domingo':
    print ("fim de semana")
else:
    print ("dia util")

# %%
#exerc 4 peça usuario e senha
usuario_correto = "admin"
senha_correta = "54321"
usuario = input("digite usuario ")
senha = input ("digite senha ")
if usuario == usuario_correto and senha_correta =="54321":
    print ("usuario e senha corretos, liberado")
else:
    print("usuario oou senha incorretos. impedido")

# %%
# Peça uma nota e a frequência do aluno. Mostre se ele foi aprovado.


nota_aluno = int(input( "nota do aluno")) 
freq_aluno = int(input("frequencia"))

nota = input ("digite nota")
frequencia = input ("digite frequencia")

if nota <=5 and frequencia <= 70:
    print("aluno reprovado")
else :
    print ("aluno aprovado")

# %%
# Peça se o aluno entregou o trabalho. Use not para verificar se ele não entregou.


entrega_trabalho = False
if not entrega_trabalho:
    print("Aluno entregou o trabalho")
else:
    print("Aluno NÃO entregou o trabalho")

# %%
 contador = 1
while contador <=10:
  print (contador)
  contador = contador + 1

# %%
# Exerc, 2 - Peça uma senha
senha_correta = "senha correta"
senha_digitada = ""


while senha_digitada != senha_correta:
      senha_digitada = input ("digite a senha:")
      if senha_digitada ==senha_correta:
          print("senha correta. liberado")
      else:
          print (" Senha incorreta:tente novamente")

# %%
#Exerc. 3  peça numeros
numero_correto = "0"
numero_digitado = ""
while numero_digitado != numero_correto:
  numero_digitado = input(" Digite um numero")
  if numero_digitado == numero_correto:
    print ("Acertou")
    else:
       print("errou. tente novamente")

# %%
# exerc. 4 - contar de 10 a 1
i = 10
while i >=1:
  print (I)
  i -= 1

# %%
# exerc. 5 - peça uma idade


idade = int(input("digite sua idade"))
while idade <=0:
  print ("idaded invalida. digite um valor positivo")
  idade = int(print(" Digite sua idade "))
  print ( f"idade valida: (idade) anos")

# %%
# exerc. 6 - menu que encerra
opcao - -1
while opcao !=0:
  print ("--------")
  print (" 1 = ver saldo")
  print (" 2 = fazer deposito")
  print (" 3 = fazer saque")
  print (" 4 = extrato")
  print (" 0 = sair")
  print ("-------------")
  opcao = int(input("escolha uma opcao"))
  if opcao ==1 :
    print("executando: ver saldo")
    elif opcao == 2:
      print("Executando: Fazer depósito")
      elif opcao == 3:
      print("Executando: fazer saque")
      elif opcao == 4:
      print("Executando: Extrato")
      elif opcao == 0:
      print("Opcao invalida: Tente novamente")
  print ("Encerrando o programa... tudo certo")
