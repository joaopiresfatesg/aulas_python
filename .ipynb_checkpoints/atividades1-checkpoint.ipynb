# %% [markdown]
# Exercício 1 Crie um programa que mostre na tela:

# %%
a ="Eu estou aprendendo python"
print(a)
# Out:
# Eu estou aprendendo python

# %% [markdown]
# Exercício 2 Crie um programa que mostre:

# %%
b="Maria"
c="Recife"
print("Meu nome é",b, "\ne moro em",c)
# Out:
# Meu nome é Maria
# e moro em Recife

# %% [markdown]
# Exercicio 3

# %%
d="Meu nome é Ana"
e="e tenho 18 anoa"
print (d,"\n",e)
# Out:
# Meu nome é Ana
#  e tenho 18 anoa

# %% [markdown]
# Exercicio 4: Crie três variáveis: cidade, estado e pais. E mostre:

# %%
entrada = input("digite seu nome")
cidade = input ("qual a cidade em que vc mora")
print("Olá", entrada,"vvc mora em",cidade)
# Out:
# digite seu nome João
# qual a cidade em que vc mora Goiania
# Olá João vvc mora em Goiania
